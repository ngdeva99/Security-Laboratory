# %%
import re
def encrypt(text,key):

    a='ABCDEFGHIJKLMNOPQRSTUVWXYZ'
    b=''
    c=len(key)
    j=0
    regex = re.compile('[@_!#$%^&*()<>?/\|}{~:]')
    if regex.search(text)!=None:
        return "The text should contain alphabets only"
    if(text.isupper()):
        for i in range(0,len(text)):
            if(text[i]==" "):
                b=b+" "
            else:
                b=b+a[(a.find(text[i])+a.find(key[j%c]))%26]
                j=j+1
    else:
        text=text.upper()
        key=key.upper()
        for i in range(0,len(text)):
            if(text[i]==" "):
                b=b+" "
            else:
                b=b+a[(a.find(text[i])+a.find(key[j%c]))%26]
                j=j+1
        b=b.lower()
        
    return b

def decrypt(text,key):
    a='ABCDEFGHIJKLMNOPQRSTUVWXYZ'
    b=''
    c=len(key)
    j=0
    regex = re.compile('[@_!#$%^&*()<>?/\|}{~:]')
    if regex.search(text)!=None:
        return "The text should contain alphabets only"
    if(text.isupper()):
        for i in range(0,len(text)):
            if(text[i]==" "):
                b=b+" "
            else:
                b=b+a[(a.find(text[i])-a.find(key[j%c]))%26]
                j=j+1
    else:
        text=text.upper()
        key=key.upper()
        for i in range(0,len(text)):
            if(text[i]==" "):
                b=b+" "
            else:
                b=b+a[(a.find(text[i])-a.find(key[j%c]))%26]
                j=j+1
        b=b.lower()
        
    return b
    

while True:
    title="VIGENERE CIPHER - Devanathan"
    print(title.center(50,'-'))
    text=input("Enter plain text:")
    s=input("Enter key:")
    print("\n1.Encrypt\n2.Decrypt")
    option=int(input("\nEnter option:"))
    if option==1:
        print("Plain Text  : " + text )
        print("Shift : ",s )
        print("Cipher: " + encrypt(text,s))
    elif option==2:
        print("Cipher Text  : " + text )
        print("Shift : ",s )
        print("Plain Text: " + decrypt(text,s))
    else:
        quit()
# Out:
# -----------VIGENERE CIPHER - Devanathan-----------
# Enter plain text:Deva
# Enter key:3
#
# 1.Encrypt
# 2.Decrypt
#
# Enter option:1
# Plain Text  : Deva
# Shift :  3
# Cipher: cduz
# -----------VIGENERE CIPHER - Devanathan-----------
# Enter plain text:cduz
# Enter key:3
#
# 1.Encrypt
# 2.Decrypt
#
# Enter option:2
# Cipher Text  : cduz
# Shift :  3
# Plain Text: deva
# -----------VIGENERE CIPHER - Devanathan-----------
